# %% [markdown]
# # Part 1: Sales volume
#
# We can import our preprocessed data

# %%
#packages
import numpy as np
import pandas as pd
import datetime as dt
import geopandas
import bokeh

df = pd.read_csv("sales_df.csv")
df.rename(columns={ df.columns[0]: "index" }, inplace = True)
df = df.set_index("index")

# %%
df.reset_index().plot(kind='scatter', x='transaction date', y='amount (merchant currency)')
# Out:
# <Axes: xlabel='transaction date', ylabel='amount (merchant currency)'>

# %%
df.loc[df["sku id"] == "unlockcharactermanager"].reset_index().plot(kind='scatter', x='transaction date', y='amount (merchant currency)')
# Out:
# <Axes: xlabel='transaction date', ylabel='amount (merchant currency)'>

# %%
df.loc[df["sku id"] == "premium"].reset_index().plot(kind='scatter', x='index', y='amount (merchant currency)')
# Out:
# <Axes: xlabel='index', ylabel='amount (merchant currency)'>
